# %% [markdown]
# 第5章　演習問題　解答例

# %% [markdown]
# 問題５－１

# %%
# *** 定義関数「func」***
def func(x):
    y = 1 + x**2
    return y

# main program(呼び出し側のプログラム)
a = 5
# 定義関数「func」の呼び出し
b = func(a)
print(b)
# Out:
# 26

# %% [markdown]
# 問題５－２

# %%
# *** 定義関数「func」***
def func(x):
    print(x)
    print(type(x))

# 文字列型変数として、m を指定
m = 'There is the method.'
func(m)
# Out:
# There is the method.
# <class 'str'>
