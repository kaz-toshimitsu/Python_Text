# %% [markdown]
# 第2章　練習問題　解答例

# %% [markdown]
# 問題２－１

# %%
x = 10
y = 100

z1 = x + y
z2 = x - y
z3 = x * y
z4 = x/y

print(z1, z2, z3, z4)
# Out:
# 110 -90 1000 0.1

# %% [markdown]
# 問題２－２

# %%
s1 ="Python is"
s2 =" easy to use."
s3 = s1 + s2
print(s3)
# Out:
# Python is easy to use.

# %% [markdown]
# 問題２－３

# %%
# 累算代入変数zの初期化
z = 1

# 10!の計算（0～9のループ演算）
for i in range(10):
    z *= i+1
    print(i+1 , z)
# Out:
# 1 1
# 2 2
# 3 6
# 4 24
# 5 120
# 6 720
# 7 5040
# 8 40320
# 9 362880
# 10 3628800

# %% [markdown]
# 問題２－４

# %%
x = 1

y = float(x)
print(y)
# Out:
# 1.0
