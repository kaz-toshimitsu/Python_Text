# %% [markdown]
# 第3章　演習問題

# %% [markdown]
# 問題３－１

# %%
# 解答例１
x = 3

if x < 5:
    print(x)
# Out:
# 3

# %%
# 解答例２
x = 10

if x < 5:
     print(x)
print(x)
# Out:
# 10

# %%
# 解答例３
x = 10

if x > 5:
    print(x)
# Out:
# 10

# %% [markdown]
# 問題３－２

# %%
# 変数ｘに数値 20 を入れる
x = 20
# xは（5より小さい）または（15より大きい）
if( (x < 5) or (x > 15) ):
    print('5より小さい）または（15より大きい）')
print(x)
# Out:
# 5より小さい）または（15より大きい）
# 20

# %% [markdown]
# 問題３－３

# %% [markdown]
# 解答例
#
# n は 1　として、
# nが0のときは、'n = 0'を表示する
# nが1のときは、'n = 1'を表示する
# それ以外は、'n > 2'を表示する
#
# プログラムを動かすと、'n = 1'が表示される
