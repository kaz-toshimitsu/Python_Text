# %% [markdown]
# 付録　プログラム

# %% [markdown]
# 初期設定

# %%
# 日本語化ライブラリ導入
# !pip install japanize-matplotlib | tail -n 1

# %%
# ライブラリのimport

# matplotlib日本語化対応ライブラリのインポート
import japanize_matplotlib

# numpy用ライブラリ
import numpy as np

# matplotlib中のpyplotライブラリのインポート
import matplotlib.pyplot as plt

# pandas用ライブラリ
import pandas as pd

# データフレーム表示用関数
from IPython.display import display

# %%
# 表示オプション調整

# NumPy表示形式の設定
np.set_printoptions(
    suppress=True, precision=4, floatmode='fixed'
)

# グラフのデフォルトフォント指定
plt.rcParams["font.size"] = 14

# サイズ設定
plt.rcParams['figure.figsize'] = (6, 6)

# 方眼表示ON
plt.rcParams['axes.grid'] = True

# データフレームでの表示精度
pd.options.display.float_format = '{:.4f}'.format

# データフレームですべての項目を表示
pd.set_option("display.max_columns",None)

# %%
# Google Colaboratoryへのマウント
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 【データの読み込みと確認】:　「dataRTHeat_4.csv」を読み込み、内容の概略の確認
# データは、Google Driveの/content/dataRTHeat_4.csvで保存されます。

# %%
# URLを指定する
url = 'https://github.com/kaz-toshimitsu/Python_Text/blob/main/dataRTHeat_4.csv'

# ファイルダウンロード( -nc: 重ね書きなし)
# !wget $url -nc -P '/content/drive/MyDrive/Colab Notebooks/Python_Txt_toshimitsu'

# ファイルの確認
# csv = 'dataRTHeat_4.csv'
# !head -3 $csv
# Out:
# --2026-01-09 14:18:51--  https://github.com/kaz-toshimitsu/Python_Text/blob/main/dataRTHeat_4.csv
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2026-01-09 14:18:52 ERROR 404: Not Found.

# %% [markdown]
# Google Colaboratoryにデータをアップロードする

# %%
# ダウンロードしたCSVファイルをデータフレーム「df」に読み込む
df = pd.read_csv(
    '/content/drive/MyDrive/Colab Notebooks/Python_Txt_toshimitsu/dataRTHeat_4.csv',
    header=None)

# 内容確認（最初の5行を表示）
display(df.head())
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /tmp/ipython-input-2144161424.py in <cell line: 0>()
#       1 # ダウンロードしたCSVファイルをデータフレーム「df」に読み込む
# ----> 2 df = pd.read_csv(
#       3     '/content/drive/MyDrive/Colab Notebooks/Python_Txt_toshimitsu/dataRTHeat_4.csv',
#       4     header=None)
#       5
#
# ...
