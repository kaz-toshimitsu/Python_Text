# %% [markdown]
# 第８章　チェック演習

# %%
# チェック演習8-1：外部ライブラリ「numpy」をつかって指数関数e^3を計算し、表示する。（付録の第8章、9章を参照）
#　外部ライブラリnumpyを利用する宣言
import numpy as np
y = np.exp(3)
print(y)
# Out:
# 20.085536923187668

# %%
# チェック演習8-2：Pythonと外部ライブラリ「numpy」を「np」としてインポートし、バージョンを表示する。
# !python -V
print('numpyのバージョン: ', np.__version__)
# Out:
# Python 3.12.12
# numpyのバージョン:  2.0.2
